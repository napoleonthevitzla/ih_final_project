# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Exportamos datasets(elegir esta opción )

#Data from berseker source
running_raw = pd.read_csv('./data/DataSet_Berseker2022_running_session.csv')
fisio_raw = pd.read_csv('./data/DataSet_Berseker_Fisio_session.csv')
mountain_raw = pd.read_csv('./data/DataSet_Berseker_Mountain_session.csv')

# %%
# We equiparate all datasets

running_raw['dia'] = pd.to_datetime(running_raw['Marca temporal'], format="%d/%m/%Y %H:%M:%S", errors='coerce')

# %%
# FISIO_RAW Data manipulation

def databerseker (dataset, activity):
    dataset['Category_fitness'] = activity
    dataset = dataset.drop(['Marca temporal'], axis=1)
    dataset['date'] = pd.to_datetime(dataset['Dia'], format="%d/%m/%Y", errors='coerce')
    dataset['year']= dataset['date'].dt.year
    dataset['month']= dataset['date'].dt.month
    dataset['day']= dataset['date'].dt.day
    dataset['week_of_year'] = dataset['date'].dt.week
    dataset['day_of_week'] = dataset['date'].dt.dayofweek
    dataset['is_leap_year'] = dataset['date'].dt.is_leap_year
    
    dw_mapping={
    0: 'Monday', 
    1: 'Tuesday', 
    2: 'Wednesday', 
    3: 'Thursday', 
    4: 'Friday',
    5: 'Saturday', 
    6: 'Sunday'
    } 
    dataset['day_of_week_name']=dataset['date'].dt.weekday.map(dw_mapping)

# %%
# FISIO_RAW Data manipulation


#Incluir columna con categoria 
fisio_raw['Category_fitness'] = "Fisio"

# Eliminar marca temporal
fisio_raw = fisio_raw.drop(['Marca temporal'], axis=1)

#Incluir semana del año y mes del año y el día de la semana

#Convert to datetime format:
fisio_raw['date'] = pd.to_datetime(fisio_raw['Dia'], format="%d/%m/%Y", errors='coerce')
# Get year, month and day
fisio_raw['year']= fisio_raw['date'].dt.year
fisio_raw['month']= fisio_raw['date'].dt.month
fisio_raw['day']= fisio_raw['date'].dt.day
# Get the week of year, the day of week and leap year
fisio_raw['week_of_year'] = fisio_raw['date'].dt.week
fisio_raw['day_of_week'] = fisio_raw['date'].dt.dayofweek
fisio_raw['is_leap_year'] = fisio_raw['date'].dt.is_leap_year

#  Map to get the day of the week 
dw_mapping={
    0: 'Monday', 
    1: 'Tuesday', 
    2: 'Wednesday', 
    3: 'Thursday', 
    4: 'Friday',
    5: 'Saturday', 
    6: 'Sunday'
} 
fisio_raw['day_of_week_name']=fisio_raw['date'].dt.weekday.map(dw_mapping)

# Incluir minutos de sesión en el dataset de Fisio con valores aleatorios entre 60 y 90 minutos

fisio_raw['Min_sesion'] = np.random.randint(60, 90, size = len(fisio_raw))
#fisio_raw['Min_sesion'] = np.random.randint(60, 90, fisio_raw.shape[0])
fisio_raw.head()
# Out:
# /Users/antoniohuerta/miniconda3/envs/ih_final_project/lib/python3.7/site-packages/ipykernel_launcher.py:19: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#                                Ejercicios Realizados  Rating Forma Física  \
# 0  5 minutos de cinta a las rodillas, 10 x 2 Sent...                    3
# 1  Estabilidad bosu, Cinta al culo, Bicicleta, Mo...                    2
# 2  5 minutos de cinta a las rodillas, 10 x 2 Sent...                    2
# 3  5 minutos de cinta a las rodillas, 10 x 2 Sent...                    2
# 4  10 x 2 Sentadilla (30 Kgs), Pelota al gluteo, ...                    4
#
#    Rating exigencia de la sesión         Dia Category_fitness       date  \
# 0                              4  20/01/2022            Fisio 2022-01-20
# 1                              3  24/01/2022            Fisio 2022-01-24
# ...

# %%
# FISIO_RAW Data manipulation

def databerseker (dataset, activity):
    dataset['Category_fitness'] = activity
    dataset = dataset.drop(['Marca temporal'], axis=1)
    dataset['date'] = pd.to_datetime(dataset['Dia'], format="%d/%m/%Y", errors='coerce')
    dataset['year']= dataset['date'].dt.year
    dataset['month']= dataset['date'].dt.month
    dataset['day']= dataset['date'].dt.day
    dataset['week_of_year'] = dataset['date'].dt.week
    dataset['day_of_week'] = dataset['date'].dt.dayofweek
    dataset['is_leap_year'] = dataset['date'].dt.is_leap_year
    
    dw_mapping={
    0: 'Monday', 
    1: 'Tuesday', 
    2: 'Wednesday', 
    3: 'Thursday', 
    4: 'Friday',
    5: 'Saturday', 
    6: 'Sunday'
    } 
    dataset['day_of_week_name']=dataset['date'].dt.weekday.map(dw_mapping)

# %%
running_raw.head()
# Out:
#         Marca temporal  Tiempo de carrera (En min) Distancia en Km Modalidad  \
# 0  10/01/2022 16:06:49                          10               1   Hibrido
# 1  13/01/2022 14:23:33                          24             4,1     Trote
# 2  19/01/2022 19:30:18                          25               4     Trote
# 3  25/01/2022 17:48:28                          29            4.66     Trote
# 4   5/02/2022 13:19:53                          20               4     Trote
#
#    Rating Forma Física  Rating exigencia de la carrera Category_fitness
# 0                    3                               2         Runnning
# 1                    2                               4         Runnning
# 2                    3                               2         Runnning
# 3                    4                               3         Runnning
# 4                    3                               2         Runnning

# %%
running = "Runnning"
mountain = "Mountain"
fisio = "Fisio"
databerseker(fisio_raw, fisio)
databerseker(running_raw,running)
databerseker(mountain_raw,mountain)
# Out:
# /Users/antoniohuerta/miniconda3/envs/ih_final_project/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   # Remove the CWD from sys.path while we load stuff.

# %%
mountain_raw.head()
# Out:
#         Marca temporal                                  Nombre de la ruta  \
# 0   28/12/2021 2:15:58                  Jarosa a cumbre alta (vía Crucis)
# 1  29/12/2021 15:49:07  Pico de la Perdiguera, puerto canencia con el ...
# 2   2/01/2022 13:05:41                            Javea Cruz del potitxol
# 3   2/01/2022 13:06:48                            Jávea parque del montgo
# 4    9/01/2022 1:35:25                                 Jávea cueva montgo
#
#           Provincia Zona concreta (Ej: Guadarrama)  Duración (en horas)  \
# 0            Madrid            Valle de los caídos                  2.0
# 1            Madrid                     Guadarrama                  2.5
# 2  Alicante/Alacant                          Javea                  2.0
# 3  Alicante/Alacant      Jávea - parque del montgo                  1.0
# 4  Alicante/Alacant            Montgo a las cuevas                  1.0
#
#   Distancia en Km Modalidad Modalidad.1  Rating Forma Física  \
# ...

# %%
# Out:
#         Marca temporal  Tiempo de carrera (En min) Distancia en Km Modalidad  \
# 0  10/01/2022 16:06:49                          10               1   Hibrido
# 1  13/01/2022 14:23:33                          24             4,1     Trote
# 2  19/01/2022 19:30:18                          25               4     Trote
# 3  25/01/2022 17:48:28                          29            4.66     Trote
# 4   5/02/2022 13:19:53                          20               4     Trote
#
#    Rating Forma Física  Rating exigencia de la carrera Category_fitness  \
# 0                    3                               2         Runnning
# 1                    2                               4         Runnning
# 2                    3                               2         Runnning
# 3                    4                               3         Runnning
# 4                    3                               2         Runnning
#
#                  date
# 0 2022-01-10 16:06:49
# 1 2022-01-13 14:23:33
# ...
